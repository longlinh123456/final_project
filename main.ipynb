# %% [markdown]
# ### Library and function imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Data processing

# %%
# Import data from response sheet (code taken from https://towardsdatascience.com/read-data-from-google-sheets-into-pandas-without-the-google-sheets-api-5c468536550/)
sheet_url = "https://docs.google.com/spreadsheets/d/1tHQbJ680xMqRb_orOCIyWieltbxuIgdtkDNnR6R69LM/edit#gid=1439117899"
url_1 = sheet_url.replace('/edit#gid=', '/export?format=csv&amp;gid=')

pd.read_csv(url_1)
# Out:
#            Dấu thời gian  1. Please specify your age:   \
# 0     14/05/2026 0:28:00                            19
# 1     14/05/2026 0:30:30                            19
# 2     14/05/2026 0:30:32                            19
# 3     14/05/2026 0:31:18                            18
# 4     14/05/2026 0:32:25                            19
# ..                   ...                           ...
# 100  14/05/2026 11:24:33                            19
# 101  14/05/2026 11:26:52                            18
# 102  14/05/2026 11:27:33                            20
# 103  14/05/2026 11:27:34                            19
# 104  14/05/2026 11:28:07                            18
#
#     2. Please select your gender:         3. Please select your College:  \
# 0                            Male  CECS (Engineering & Computer Science)
# 1                          Female          CBM (Business and Management)
# 2                            Male  CECS (Engineering & Computer Science)
# ...
